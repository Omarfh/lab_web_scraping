# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
#import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
response = requests.get(url)
html = response.content
print(html)
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-AKSyLOJ6AQw0AfEns1dcdb1yzblAu0EvvS3Fkne6Gy+XrHAJ89KrNnSjDXBRkKkUVmaLgQsIAKQ8L3de68HGmQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-00a4b22ce27a010c3401f127b3575c75.css" /><link crossorigin="anonymous" media="all" integrity="sha512-oDSXh/8y26DqbQ7O8sdd6IqcHA7B1BQrMEMIy7h2lCFCXgi0ffXaKjkwd6eIWl0AIWUbKVtewbJUN
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
soup = BeautifulSoup(html, 'lxml')

elements = soup.select('h1.h3 a[data-view-component="true"]')
elements
# Out:
# [<a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":283842,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="3dc94c60d8252619e47562467da3d5d9a10c60545f4f5127a11dee99ed4ed5e8" data-view-component="true" href="/nolanlawson">
#              Nolan Lawson
#  </a>,
#  <a data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":17802178,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="89d955064890fd6b2591a6a2f220e6f2eb8777ef3213844d4a3e030ae639517a" data-view-component="true" href="/gakonst">
#              Georgios Konstantopoulos
#  </a>,
# ...

# %%
elements2 = soup.select('p a[class="Link--secondary"]')
nicknames = [nickname.text.strip() for nickname in elements2]
nicknames
# Out:
# ['nolanlawson',
#  'gakonst',
#  'williamboman',
#  'adamchainz',
#  'vmihailenco',
#  'johnlindquist',
#  'unknwon',
#  'wcandillon',
#  'rennokki',
#  'avelino',
#  'felangel',
#  'Koenkk',
#  'qarmin',
#  'twpayne',
#  'nschloe',
#  'fonsp',
#  'andig',
#  'asim',
#  'deivid-rodriguez',
#  'lpil',
#  'vincenzopalazzo',
#  'carlmjohnson',
#  'postlund',
#  'timlrx',
#  'laurent22']

# %%
names = [name.text.strip() for name in elements]
names
# Out:
# ['Nolan Lawson',
#  'Georgios Konstantopoulos',
#  'William Boman',
#  'Adam Johnson',
#  'Vladimir Mihailenco',
#  'John Lindquist',
#  'Joe Chen',
#  'William Candillon',
#  'rennokki',
#  'Avelino',
#  'Felix Angelov',
#  'Koen Kanters',
#  'Rafał Mikrut',
#  'Tom Payne',
#  'Nico Schlömer',
#  'Fons van der Plas',
#  'andig',
#  'Asim Aslam',
#  'David Rodríguez',
#  'Louis Pilfold',
#  'Vincenzo Palazzo',
#  'Carl Johnson',
#  'Pierre Ståhl',
#  'Timothy',
#  'Laurent']

# %%
trending_dev = [names[i]+' ('+nicknames[i]+')' for i in range(len(names))]
trending_dev
# Out:
# ['Nolan Lawson (nolanlawson)',
#  'Georgios Konstantopoulos (gakonst)',
#  'William Boman (williamboman)',
#  'Adam Johnson (adamchainz)',
#  'Vladimir Mihailenco (vmihailenco)',
#  'John Lindquist (johnlindquist)',
#  'Joe Chen (unknwon)',
#  'William Candillon (wcandillon)',
#  'rennokki (rennokki)',
#  'Avelino (avelino)',
#  'Felix Angelov (felangel)',
#  'Koen Kanters (Koenkk)',
#  'Rafał Mikrut (qarmin)',
#  'Tom Payne (twpayne)',
#  'Nico Schlömer (nschloe)',
#  'Fons van der Plas (fonsp)',
#  'andig (andig)',
#  'Asim Aslam (asim)',
#  'David Rodríguez (deivid-rodriguez)',
#  'Louis Pilfold (lpil)',
#  'Vincenzo Palazzo (vincenzopalazzo)',
#  'Carl Johnson (carlmjohnson)',
#  'Pierre Ståhl (postlund)',
#  'Timothy (timlrx)',
#  'Laurent (laurent22)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'lxml')
elements = soup.select('h1 a[data-view-component="true"]')
url_base = 'https://github.com'

#elements[0]['href']
repos = [url_base+elements[i]['href'] for i in range(len(elements))]
repos
# Out:
# ['https://github.com/yt-dlp/yt-dlp',
#  'https://github.com/xinntao/Real-ESRGAN',
#  'https://github.com/bottlesdevs/Bottles',
#  'https://github.com/521xueweihan/HelloGitHub',
#  'https://github.com/freqtrade/freqtrade',
#  'https://github.com/ytdl-org/youtube-dl',
#  'https://github.com/tiangolo/fastapi',
#  'https://github.com/vt-vl-lab/3d-photo-inpainting',
#  'https://github.com/home-assistant/core',
#  'https://github.com/Pycord-Development/pycord',
#  'https://github.com/isocpp/CppCoreGuidelines',
#  'https://github.com/DIGITALCRIMINAL/OnlyFans',
#  'https://github.com/Music-and-Culture-Technology-Lab/omnizart',
#  'https://github.com/niubiqigai/turtle',
#  'https://github.com/luminoleon/epicgames-claimer',
#  'https://github.com/rentruewang/koila',
#  'https://github.com/wjf5203/SeqFormer',
#  'https://github.com/SecuProject/ADenum',
#  'https://github.com/ankitects/anki',
#  'https://github.com/Chia-Network/chia-blockchain',
#  'https://github.com/QUANTAXIS/QUANTAXIS',
# ...

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'lxml')
url_base = 'https://en.wikipedia.org'
elements = soup.select('div a[class="image"]')
#elements[0]['href']
images = [url_base+elements[i]['href'] for i in range(len(elements))]
images
# Out:
# ['https://en.wikipedia.org/wiki/File:Walt_Disney_1946.JPG',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_1942_signature.svg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  'https://en.wikipedia.org/wiki/File:Trolley_Troubles_poster.jpg',
#  'https://en.wikipedia.org/wiki/File:Steamboat-willie.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_1935.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  'https://en.wikipedia.org/wiki/File:Disney_drawing_goofy.jpg',
#  'https://en.wikipedia.org/wiki/File:DisneySchiphol1951.jpg',
#  'https://en.wikipedia.org/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_disney_portrait_right.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_Grave.JPG',
#  'https://en.wikipedia.org/wiki/File:Roy_O._Disney_with_Company_at_Press_Conference.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python_(programming_language)'

# %%
#your code
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, 'html')
# print(soup)
links_p = soup.select('p a')
# links_p
links_p_wcites = [links_p[i]['href'] for i,x in enumerate(links_p)] # 'https:/'+
links_p_clean = [link for link in links_p_wcites if link.startswith('#') == False]
links_p_clean
# Out:
# ['/wiki/Interpreted_language',
#  '/wiki/High-level_programming_language',
#  '/wiki/General-purpose_programming_language',
#  '/wiki/Code_readability',
#  '/wiki/Off-side_rule',
#  '/wiki/Language_construct',
#  '/wiki/Object-oriented_programming',
#  '/wiki/Programmers',
#  '/wiki/Type_system#DYNAMIC',
#  '/wiki/Garbage_collection_(computer_science)',
#  '/wiki/Programming_paradigm',
#  '/wiki/Structured_programming',
#  '/wiki/Procedural_programming',
#  '/wiki/Functional_programming',
#  '/wiki/Standard_library',
#  '/wiki/Guido_van_Rossum',
#  '/wiki/ABC_(programming_language)',
#  '/wiki/List_comprehension',
#  '/wiki/Cycle_detection',
#  '/wiki/Reference_counting',
#  '/wiki/Backward_compatibility',
#  '/wiki/Guido_van_Rossum',
#  '/wiki/Centrum_Wiskunde_%26_Informatica',
#  '/wiki/Netherlands',
#  '/wiki/ABC_(programming_language)',
#  '/wiki/SETL',
#  '/wiki/Exception_handling',
#  '/wiki/Amoeba_(operating_system)',
#  '/wiki/Benevolent_dictator_for_life',
# ...

# %%
links = soup.find_all('a', href=True)
# links[0]["href"]
links_href = [links[i]["href"] for i in range(len(links))]
links_clean = [link for link in links_href if link.startswith("#") == False]
links_clean
links_python = links_p_clean
for link in links_clean:
    links_python.append(link)

links_python_clean = list(set(links_python))
links_python_cl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ebc9aed4cdbd> in <module>
#       9
#      10 links_python_clean = list(set(links_python))
# ---> 11 links_python_cl
#
# NameError: name 'links_python_cl' is not defined

# %%
links_python = [url_base+elements[i]['href'] for i in range(len(elements))]
links_python
# Out:
# ['https://en.wikipedia.org/wiki/Enez',
#  'https://en.wikipedia.org/wiki/Help:IPA/English',
#  'https://en.wikipedia.org/wiki/Greek_language',
#  'https://en.wikipedia.org/wiki/Greek_philosophy',
#  'https://en.wikipedia.org/wiki/Plato',
#  'https://en.wikipedia.org#cite_note-1',
#  'https://en.wikipedia.org/wiki/Heraclides_of_Aenus',
#  'https://en.wikipedia.org/wiki/Cotys_I_(Odrysian)',
#  'https://en.wikipedia.org/wiki/Thrace',
#  'https://en.wikipedia.org#cite_note-2',
#  'https://en.wikipedia.org/wiki/Demosthenes',
#  'https://en.wikipedia.org/wiki/Python_of_Byzantium',
#  'https://en.wikipedia.org#cite_note-3',
#  'https://en.wikipedia.org/wiki/Wikipedia:Stub',
#  'https://en.wikipedia.orghttps://en.wikipedia.org/w/index.php?title=Python_of_Aenus&action=edit',
#  'https://en.wikipedia.org/wiki/Wikipedia:Stub',
#  'https://en.wikipedia.orghttps://en.wikipedia.org/w/index.php?title=Python_of_Aenus&action=edit']

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, 'html')
titles = soup.select("div.usctitle")
titles_text = [title.text.strip() for title in titles]
titles_clean = titles_text[2:]
titles_clean
# Out:
# ['Title 1 - General Provisions ٭',
#  'Title 2 - The Congress',
#  'Title 3 - The President ٭',
#  'Title 4 - Flag and Seal, Seat of Government, and the States ٭',
#  'Title 5 - Government Organization and Employees ٭',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 9 - Arbitration ٭',
#  'Title 10 - Armed Forces ٭',
#  'Title 11 - Bankruptcy ٭',
#  'Title 12 - Banks and Banking',
#  'Title 13 - Census ٭',
#  'Title 14 - Coast Guard ٭',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights ٭',
#  'Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 19 - Customs Duties',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways ٭',
#  'Title 24 - Hospitals and Asylums',
#  'Title 25 - Indians',
#  'Title 26 - Internal Revenue Code',
#  'Title 27 - Intoxicating Liquors',
# ...

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html')
most_wanted_list = soup.select('h3.title a')
most_wanted = [wanted.text.strip() for wanted in most_wanted_list]
most_wanted
# Out:
# ['JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'OCTAVIANO JUAREZ-CORRO',
#  'RAFAEL CARO-QUINTERO',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'EUGENE PALMER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, 'html.parser')
table_dates = soup.select('tbody td a')
quake_dates = [table_dates[i].text.replace('\xa0',' ') for i in range(len(table_dates))] # .replace('\xa0',' ').replace(' ','')
table_lat_num = soup.select('tbody tr td.tabev1')
quake_lat_num = [table_lat_num[i].text.replace('\xa0',' ') for i in range(len(table_lat_num))]
table_lat_dir = soup.select('tbody tr td.tabev2')
quake_lat_dir = [table_lat_dir[i].text.replace('\xa0',' ') for i in range(len(table_lat_dir))]
quake_lat = [num+' '+d for num, d in zip(quake_lat_num, quake_lat_dir)]
quake_lat
# Out:
# ['18.84  N  ',
#  '155.21  W  ',
#  '35.50  2.9',
#  '3.63  N  ',
#  '37.74  W  ',
#  '71.59  3.7',
#  '35.15  S  ',
#  '3.87  W  ',
#  '23.30  3.4',
#  '68.56  N  ',
#  '40.54  W  ',
#  '124.22  3.4',
#  '38.14  S  ',
#  '38.77  W  ',
#  '40.37  2.7',
#  '124.24  N  ',
#  '40.48  W  ',
#  '124.30  2.7',
#  '63.21  N  ',
#  '150.44  E  ',
#  '28.56  2.7',
#  '17.84  N  ',
#  '19.21  W  ',
#  '155.48  2.8',
#  '42.75  N  ',
#  '16.13  W  ',
#  '40.56  2.3',
#  '124.50  N  ',
#  '45.92  W  ',
#  '10.89  2.9',
#  '36.22  N  ',
#  '36.01  W  ',
#  '40.44  2.3',
#  '124.29  N  ',
#  '40.49  W  ',
#  '124.33  2.1',
#  '40.26  N  ',
#  '125.23  E  ',
#  '28.58  2.7',
#  '17.90  N  ',
#  '40.37  W  ',
#  '124.26  2.9',
#  '17.94  N  ',
#  '66.84  E  ',
#  '0.61  2.1',
#  '131.54  N  ',
#  '40.27  E  ',
#  '124.77  2.1',
#  '40.31  N  ',
#  '124.77  W  ',
#  '1.31  2.8',
#  '120.47  N  ',
#  '22.35  W  ',
#  '143.74  2.1',
#  '19.18  N  ',
#  '155.46  W  ',
#  '40.35  2.7',
#  '124.49  N  ',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-e699a700df10> in <module>
#       1 # quake[0][:10]+' '+quake[0][10:20]+' '+quake[0][20:30]+' '+quake[0][30:38]+' '+quake[0][38:50]
# ----> 2 quake
#       3 # eq = [item.split() for item in quake]
#       4 # eq[0]
#       5 # df2 = pd.DataFrame(eq)
#
# NameError: name 'quake' is not defined

# %%
date_time_list[0]
# Out:
# '2021-12-21   00:31:58.2'

# %%
eq[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-8c91dcab36ae> in <module>
# ----> 1 eq[3]
#
# NameError: name 'eq' is not defined

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#yourcode

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
ljj
